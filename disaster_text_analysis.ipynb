# %%
import pandas as pd
import numpy as np
import plotly.express as px
import joblib
import matplotlib.pyplot as plt

# %%
insta_posts = pd.read_csv('Instagram posts.csv')

# %%
insta_post = insta_posts[[ 'caption', 'id', 'locationId', 'locationName', 'ownerFullName', 'ownerId', 'ownerUsername', 'timestamp']]
hashtags = insta_posts[[f'hashtags/{i}' for i in range(30)]]
insta_posts = pd.concat([insta_post, hashtags], axis=1)

# %%
insta_posts
# Out:
#                                                caption                   id  \
# 0    30 Dead, Over 500 Stranded As Himachal Pradesh...  3144332908423964840
# 1    ਹੜ ਕਾਰਨ ਬੇਘਰ ਹੋਏ ਲੋਕਾਂ ਲਈ ਸਰਕਾਰ ਵੱਲੋਂ ਰਾਖਵੀਂ ਕ...  3144333792524601542
# 2    భారీ వర్షాలు ఉత్తరాదిని వణికిస్తున్నాయి. ఢిల్ల...  3144332119812074456
# 3    The Yamuna in Delhi has exceeded the evacuatio...  3144323671550839497
# 4    DO FOLLOW @software_santha for more updates\n....  3144332111950871566
# ..                                                 ...                  ...
# 195  #road #flood #rain #Gurgaon #City #Citylife #G...                  NaN
# 196  Are you scared of thunder?⚡️\nIn frame @jha_re...                  NaN
# 197  पटना में बीते कुछ दिनों से बारिश नही हुई जिसकी...                  NaN
# 198  Rainy day in Kyoto🌂\nNinenzaka #二年坂 🌧\n\n#phot...                  NaN
# 199  ɴᴀᴛᴜʀᴇ'ꜱ ᴄᴀɴᴠᴀꜱ!🎨🏍️\n\n 📸  @raj_shubham45\n#na...                  NaN
#
#       locationId locationName    ownerFullName       ownerId    ownerUsername  \
# 0            NaN          NaN         PMNEWS24  5.503525e+10   pmnews24portal
# 1            NaN          NaN   Patiala Public  6.097173e+10    patialapublic
# 2            NaN          NaN  MyCityHyderabad  5.813841e+10   mycityhydmedia
# 3    213262633.0        Delhi      The insider  6.035445e+10  theinsider_news
# 4            NaN          NaN  Software_santha  3.466990e+10  software_santha
# ..           ...          ...              ...           ...              ...
# 195          NaN          NaN              NaN           NaN              NaN
# 196          NaN          NaN              NaN           NaN              NaN
# 197          NaN          NaN              NaN           NaN              NaN
# 198          NaN          NaN              NaN           NaN              NaN
# 199          NaN          NaN              NaN           NaN              NaN
#
#                     timestamp   hashtags/0      hashtags/1  ...  hashtags/20  \
# 0    2023-07-11T05:35:13.000Z     pmnews24          floods  ...          NaN
# 1    2023-07-11T05:36:59.000Z      patiala          floods  ...          NaN
# 2    2023-07-11T05:33:39.000Z  NorthStates  mycityhydmedia  ...  pedestrains
# 3    2023-07-11T05:16:52.000Z        flood        flooding  ...  remediation
# 4    2023-07-11T05:33:38.000Z         news          floods  ...          NaN
# ..                        ...          ...             ...  ...          ...
# 195                       NaN          NaN             NaN  ...          NaN
# 196                       NaN          NaN             NaN  ...          NaN
# 197                       NaN          NaN             NaN  ...          NaN
# 198                       NaN          NaN             NaN  ...          NaN
# 199                       NaN          NaN             NaN  ...          NaN
#
#          hashtags/21  hashtags/22 hashtags/23 hashtags/24 hashtags/25  \
# 0                NaN          NaN         NaN         NaN         NaN
# 1                NaN          NaN         NaN         NaN         NaN
# 2         cropfields  waterlogged    Redalert         IMD  Telugunews
# 3    watermitigation       floods     weather       river   hurricane
# 4                NaN          NaN         NaN         NaN         NaN
# ..               ...          ...         ...         ...         ...
# 195              NaN          NaN         NaN         NaN         NaN
# 196              NaN          NaN         NaN         NaN         NaN
# 197              NaN          NaN         NaN         NaN         NaN
# 198              NaN          NaN         NaN         NaN         NaN
# 199              NaN          NaN         NaN         NaN         NaN
#
#     hashtags/26 hashtags/27 hashtags/28  hashtags/29
# 0           NaN         NaN         NaN          NaN
# 1           NaN         NaN         NaN          NaN
# 2       updates         NaN         NaN          NaN
# 3        kerala        life       india  moldremoval
# 4           NaN         NaN         NaN          NaN
# ..          ...         ...         ...          ...
# 195         NaN         NaN         NaN          NaN
# 196         NaN         NaN         NaN          NaN
# 197         NaN         NaN         NaN          NaN
# 198         NaN         NaN         NaN          NaN
# 199         NaN         NaN         NaN          NaN
#
# [200 rows x 38 columns]

# %%
# %pip install googletrans==3.1.0a0
# Out:
# Collecting googletrans==3.1.0a0
#   Downloading googletrans-3.1.0a0.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting httpx==0.13.3 (from googletrans==3.1.0a0)
#   Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2024.2.2)
# Collecting hstspreload (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading hstspreload-2024.2.1-py3-none-any.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.3.0)
# Collecting chardet==3.* (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 15.3 MB/s eta 0:00:00
# Collecting idna==2.* (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.6 MB/s eta 0:00:00
# Collecting rfc3986<2,>=1.3 (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting httpcore==0.9.* (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 5.0 MB/s eta 0:00:00
# Collecting h11<0.10,>=0.8 (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 7.0 MB/s eta 0:00:00
# Collecting h2==3.* (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 8.4 MB/s eta 0:00:00
# Collecting hyperframe<6,>=5.2.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Collecting hpack<4,>=3.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-3.1.0a0-py3-none-any.whl size=16352 sha256=52797822fcbc042f8a1a2036f04ccf4a7b6dbe3e878d3e3d68d4fe67db92bbbe
#   Stored in directory: /root/.cache/pip/wheels/50/5d/3c/8477d0af4ca2b8b1308812c09f1930863caeebc762fe265a95
# Successfully built googletrans
# Installing collected packages: rfc3986, hyperframe, hpack, h11, chardet, idna, hstspreload, h2, httpcore, httpx, googletrans
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
# Successfully installed chardet-3.0.4 googletrans-3.1.0a0 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2024.2.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 idna-2.10 rfc3986-1.5.0

# %%
from googletrans import Translator

translator = Translator()

insta_posts['caption'] = insta_posts.caption.apply(lambda x: translator.translate(x).text)
insta_posts
# Out:
#                                                caption                   id  \
# 0    30 Dead, Over 500 Stranded As Himachal Pradesh...  3144332908423964840
# 1    Places reserved by the government for people d...  3144333792524601542
# 2    Heavy rains lash the north. Heavy rains are fa...  3144332119812074456
# 3    The Yamuna in Delhi has exceeded the evacuatio...  3144323671550839497
# 4    DO FOLLOW @software_santha for more updates\n....  3144332111950871566
# ..                                                 ...                  ...
# 195  #road #flood #rain #Gurgaon #City #Citylife #G...                  NaN
# 196  Are you scared of thunder?⚡️\nIn frame @jha_re...                  NaN
# 197  There has been no rain in Patna for the last f...                  NaN
# 198  Rainy day in Kyoto🌂\nNinenzaka #Ninenzaka 🌧\n\...                  NaN
# 199  ɴᴀᴛᴜʀᴇ'ꜱ ᴄᴀɴᴠᴀꜱ!🎨🏍️\n\n 📸 @raj_shubham45\n#nat...                  NaN
#
#       locationId locationName    ownerFullName       ownerId    ownerUsername  \
# 0            NaN          NaN         PMNEWS24  5.503525e+10   pmnews24portal
# 1            NaN          NaN   Patiala Public  6.097173e+10    patialapublic
# 2            NaN          NaN  MyCityHyderabad  5.813841e+10   mycityhydmedia
# 3    213262633.0        Delhi      The insider  6.035445e+10  theinsider_news
# 4            NaN          NaN  Software_santha  3.466990e+10  software_santha
# ..           ...          ...              ...           ...              ...
# 195          NaN          NaN              NaN           NaN              NaN
# 196          NaN          NaN              NaN           NaN              NaN
# 197          NaN          NaN              NaN           NaN              NaN
# 198          NaN          NaN              NaN           NaN              NaN
# 199          NaN          NaN              NaN           NaN              NaN
#
#                     timestamp   hashtags/0      hashtags/1  ...  hashtags/20  \
# 0    2023-07-11T05:35:13.000Z     pmnews24          floods  ...          NaN
# 1    2023-07-11T05:36:59.000Z      patiala          floods  ...          NaN
# 2    2023-07-11T05:33:39.000Z  NorthStates  mycityhydmedia  ...  pedestrains
# 3    2023-07-11T05:16:52.000Z        flood        flooding  ...  remediation
# 4    2023-07-11T05:33:38.000Z         news          floods  ...          NaN
# ..                        ...          ...             ...  ...          ...
# 195                       NaN          NaN             NaN  ...          NaN
# 196                       NaN          NaN             NaN  ...          NaN
# 197                       NaN          NaN             NaN  ...          NaN
# 198                       NaN          NaN             NaN  ...          NaN
# 199                       NaN          NaN             NaN  ...          NaN
#
#          hashtags/21  hashtags/22 hashtags/23 hashtags/24 hashtags/25  \
# 0                NaN          NaN         NaN         NaN         NaN
# 1                NaN          NaN         NaN         NaN         NaN
# 2         cropfields  waterlogged    Redalert         IMD  Telugunews
# 3    watermitigation       floods     weather       river   hurricane
# 4                NaN          NaN         NaN         NaN         NaN
# ..               ...          ...         ...         ...         ...
# 195              NaN          NaN         NaN         NaN         NaN
# 196              NaN          NaN         NaN         NaN         NaN
# 197              NaN          NaN         NaN         NaN         NaN
# 198              NaN          NaN         NaN         NaN         NaN
# 199              NaN          NaN         NaN         NaN         NaN
#
#     hashtags/26 hashtags/27 hashtags/28  hashtags/29
# 0           NaN         NaN         NaN          NaN
# 1           NaN         NaN         NaN          NaN
# 2       updates         NaN         NaN          NaN
# 3        kerala        life       india  moldremoval
# 4           NaN         NaN         NaN          NaN
# ..          ...         ...         ...          ...
# 195         NaN         NaN         NaN          NaN
# 196         NaN         NaN         NaN          NaN
# 197         NaN         NaN         NaN          NaN
# 198         NaN         NaN         NaN          NaN
# 199         NaN         NaN         NaN          NaN
#
# [200 rows x 38 columns]

# %%
insta_posts['hashtags/0'].value_counts()
# Out:
# floods             12
# flood               6
# India               4
# patiala             3
# himachalpradesh     3
#                    ..
# hatkee              1
# Punjab              1
# Be                  1
# drug                1
# ഇരുട്ട്             1
# Name: hashtags/0, Length: 73, dtype: int64

# %%
hashtags.value_counts()
# Out:
# hashtags/0                    hashtags/1        hashtags/2    hashtags/3                                                                                                                                                                                                                                                                                                               hashtags/4              hashtags/5           hashtags/6    hashtags/7       hashtags/8                                                                                                                                                                                                                                                                                                               hashtags/9           hashtags/10         hashtags/11           hashtags/12        hashtags/13                                                                                                                                                                                                                                                                                                              hashtags/14              hashtags/15                    hashtags/16             hashtags/17        hashtags/18                                                                                                                                                                                                                                                                                                             hashtags/19             hashtags/20                 hashtags/21          hashtags/22           hashtags/23                                                                                                                                                                                                                                                                                                              hashtags/24                   hashtags/25             hashtags/26               hashtags/27         hashtags/28                                                                                                                                                                                                                                                                                                                hashtags/29
# flood                         flooding          waterdamage   water                                                                                                                                                                                                                                                                                                                    rain                    nature               restoration   insurance        mold                                                                                                                                                                                                                                                                                                                     fire                 flooddamage         storm                 firedamage         disaster                                                                                                                                                                                                                                                                                                                 photography              climatechange                  waterdamagerestoration  propertydamage     covid                                                                                                                                                                                                                                                                                                                   moldremediation         remediation                 watermitigation      floods                weather                                                                                                                                                                                                                                                                                                                  river                         hurricane               kerala                    life                india                                                                                                                                                                                                                                                                                                                      moldremoval               3
# POI - PHOTOGRAPHERS OF INDIA  1489097775        FALSE         https://instagram.ftpa1-2.fna.fbcdn.net/v/t51.2885-19/37750115_275849349867816_8807310355798687744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.ftpa1-2.fna.fbcdn.net&_nc_cat=100&_nc_ohc=sTEgmPZC_wEAX9zgKsd&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfDeM9-aGWS9C7jHH3GpnbdhTm53pdmKfF36CBpqoCDDLQ&oe=64B111C6&_nc_sid=2999b8    photographers_of_india  Photography📸| 500k™  44491663246   FALSE            https://instagram.ftpa1-2.fna.fbcdn.net/v/t51.2885-19/209559105_606729573626471_7596367602086812641_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.ftpa1-2.fna.fbcdn.net&_nc_cat=111&_nc_ohc=BYX-z8WnxaIAX8yj0wG&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfAUy_8W-2fpLDDu8id6Y2ceLE_jwbwzVVRUDZeNmK75xg&oe=64B235E0&_nc_sid=2999b8   photography_hub_203  Kunal Malhotra      1351998591            FALSE              https://instagram.ftpa1-2.fna.fbcdn.net/v/t51.2885-19/122018937_130648505462618_7637296908760604875_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.ftpa1-2.fna.fbcdn.net&_nc_cat=102&_nc_ohc=WULGQb-KNuAAX84-yTL&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfCgQdThNP2T2C-HFXqT-sTVwYUDEnYNr5rZmjQ8St3ZtA&oe=64B28B80&_nc_sid=2999b8   the.photography.blogger  Insta Photography Club | 300K  4272804729              FALSE              https://instagram.ftpa1-2.fna.fbcdn.net/v/t51.2885-19/345419443_256624263567518_2263828474819834347_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.ftpa1-2.fna.fbcdn.net&_nc_cat=102&_nc_ohc=xRpeL2dBVq8AX_Fv7AM&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfADH6tiHn2S9B1-EgKm5RExglhThoW-KZtw9-DxItMqmw&oe=64B0EE96&_nc_sid=2999b8  insta_photography_club  📸Pʜᴏᴛᴏɢʀᴀᴍ Kᴇʀᴀʟᴀ  ™✨💫      8514713072           FALSE                 https://instagram.ftpa1-1.fna.fbcdn.net/v/t51.2885-19/305541454_466225958531887_2365713547979945057_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.ftpa1-1.fna.fbcdn.net&_nc_cat=107&_nc_ohc=_eJi_QYJsw0AX9mUIWw&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfCh6oj3Y1EEGNUiEeSs68EHoJs0JD_QB6s68LUvQu7CuA&oe=64B25DDC&_nc_sid=2999b8   photogramkerala_              mobile_clickzzz_kerala  7372244000                FALSE               https://instagram.ftpa1-2.fna.fbcdn.net/v/t51.2885-19/243066563_354008173138648_8732611040744826956_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.ftpa1-2.fna.fbcdn.net&_nc_cat=104&_nc_ohc=nJAY3HuYX90AX_D_ZKI&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfDKYGZtUr9p4UvUqHxJXzUmwbg-Cho3klHAO06itJQ0yw&oe=64B0E8AA&_nc_sid=2999b8     mobile_clickzzz_kerala    1
#                                                               https://scontent-iad3-2.cdninstagram.com/v/t51.2885-19/37750115_275849349867816_8807310355798687744_n.jpg?stp=dst-jpg_s150x150&_nc_ht=scontent-iad3-2.cdninstagram.com&_nc_cat=100&_nc_ohc=sTEgmPZC_wEAX_lW30j&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfAHZnOdMudC1yqKNF3DUDXCrCILRfWFv9yuXxPZL_YCew&oe=64B111C6&_nc_sid=2999b8  photographers_of_india  Nature inFocus       2920081747    TRUE             https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/152786267_444686370302015_5633844509812207619_n.jpg?stp=dst-jpg_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=1&_nc_ohc=9ElQDYSeA4IAX8DnB2K&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfDCTyOlipjAzgRFESYh83acxaWSpvIv3u3kr_DB48PoYQ&oe=64B147EF&_nc_sid=2999b8   naturein_focus       photographys        4728099268            FALSE              https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/44781814_709021806151304_3846277186482864128_n.jpg?stp=dst-jpg_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=108&_nc_ohc=Eh-nTeaiRhYAX9WoI2-&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfBZCUVsTDnpxXwEU1TSOMRIzeckZoEql0r7M0r03QptEA&oe=64B14D2D&_nc_sid=2999b8  photographys__love       IG ⊕ BHOPAL ®                  2001885949              FALSE              https://scontent-iad3-1.cdninstagram.com/v/t51.2885-19/13774390_115428265570318_1561320463_a.jpg?stp=dst-jpg_s150x150&_nc_ht=scontent-iad3-1.cdninstagram.com&_nc_cat=110&_nc_ohc=IedB_B8PVjcAX_5GiDa&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfBW9naKzgtA42UUfvc0bCFVzjqQmT2qhjo8vtfNvtEBZA&oe=64B11715&_nc_sid=2999b8          ig.bhopal               picture_perfect             21628438597          FALSE                 https://scontent-iad3-2.cdninstagram.com/v/t51.2885-19/100541538_574603860125159_519188127915442176_n.jpg?stp=dst-jpg_s150x150&_nc_ht=scontent-iad3-2.cdninstagram.com&_nc_cat=111&_nc_ohc=ozIBt7Lt7HwAX_kFjru&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfDLURLPLdpRZw_WCZy56uX6m7HTcJck1ZaOG59WORDcPQ&oe=64B0FA4A&_nc_sid=2999b8  photography_prowess           Nature Photography 📸    51464438242               FALSE               https://scontent-iad3-2.cdninstagram.com/v/t51.2885-19/357844816_1227222554614944_2709262301216340022_n.jpg?stp=dst-jpg_s150x150&_nc_ht=scontent-iad3-2.cdninstagram.com&_nc_cat=100&_nc_ohc=_xBvhnhd8UQAX_dF4wM&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfAC5uNvsV83YSHAHvCwiVA3nNb89fm6mIUlFjq-EevwiQ&oe=64B1C02A&_nc_sid=2999b8  creative_capture019       1
# Sutlej                        sutluj            satluj        satlujriver                                                                                                                                                                                                                                                                                                              sutlejriver             punjab               punjabfloods  punjabistatus    floods                                                                                                                                                                                                                                                                                                                   india                river               sunset                sunsetphotography  dusk                                                                                                                                                                                                                                                                                                                     nature                   naturephotography              naturesfury             viral              yolo                                                                                                                                                                                                                                                                                                                    globalwarming           rains                       climatechange        godblessus            god                                                                                                                                                                                                                                                                                                                      godblessyou                   phonephotography        bridge                    bridgephotography   fyp                                                                                                                                                                                                                                                                                                                        trending                  1
# aiart                         ai                latest        latestnews                                                                                                                                                                                                                                                                                                               artcommunity            futureofai           aifuture      aiartcommunity   journalist                                                                                                                                                                                                                                                                                                               midjourneyai         dailynews           newsupdate            breakingnews       trending                                                                                                                                                                                                                                                                                                                 worldnews                midjourneyv5                   stablediffusion         todaynews          newstoday                                                                                                                                                                                                                                                                                                               artificialintelligence  news                        newspaper            journalism            midjourney                                                                                                                                                                                                                                                                                                               topnews                       floodrelief             flooded                   flood               floods                                                                                                                                                                                                                                                                                                                     flooding                  1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         landslides              landslide                 flood               flooding                                                                                                                                                                                                                                                                                                                   floods                    1
# drug                          drugaddiction     lahore        ir                                                                                                                                                                                                                                                                                                                       internationalrelations  drugfree             dawn          dailydawn        newspaper                                                                                                                                                                                                                                                                                                                css                  pms                 LAW                   internationallaw   pakistan                                                                                                                                                                                                                                                                                                                 islamabad                articleoftheday                editorial               musabsaeed         learnwithmusabsaeed                                                                                                                                                                                                                                                                                                     democracy               politics                    monsoon              rain                  floods                                                                                                                                                                                                                                                                                                                   climatechange                 urbanflooding           disaster                  disastermanagement  india                                                                                                                                                                                                                                                                                                                      sindh                     1
# flood                         floods            delhi         gurgaon                                                                                                                                                                                                                                                                                                                  gurugram                memes😂               memes         indianmemes      memegram                                                                                                                                                                                                                                                                                                                 davian               delhimemes          ncr                   delhincr           dipsite                                                                                                                                                                                                                                                                                                                  dps                      likesforlike                   likeforlikes            relatable          josephite                                                                                                                                                                                                                                                                                                               kvians                  waterpark                   followforfollowback  gainfollowtrain       meme                                                                                                                                                                                                                                                                                                                     sarcasm                       humor                   sarcasticmemes            funnymemes          funny                                                                                                                                                                                                                                                                                                                      cybercity                 1
# gospelofjohn                  johnsgospel       johnofpatmos  johntheapostle                                                                                                                                                                                                                                                                                                           bible                   torah                wordsoflove   wordofgod        truthofgod                                                                                                                                                                                                                                                                                                               truthseeker          muslims             jews                  christians         buddist                                                                                                                                                                                                                                                                                                                  hindus                   freethinkers                   climatechange           pestilence         drought                                                                                                                                                                                                                                                                                                                 floods                  heatwave                    wrathofgod           truth                 europe                                                                                                                                                                                                                                                                                                                   asia                          americas                australia                 newzealand          india                                                                                                                                                                                                                                                                                                                      china                     1
# gurudwara                     punjab            haryana       india                                                                                                                                                                                                                                                                                                                    panchkula               chandigarh           mohali        delhi            sikhtemple                                                                                                                                                                                                                                                                                                               sikhhistory          gadar2              sikhworld             sikhiam            canada                                                                                                                                                                                                                                                                                                                   amritsar                 jalandhar                      ludhiana                bhatinda           sidhumoosewala                                                                                                                                                                                                                                                                                                          diljitdosanjh           sonambajwa                  jaani                floods                rain                                                                                                                                                                                                                                                                                                                     weather                       himachal                gurdaspur                 pathankot           ropar                                                                                                                                                                                                                                                                                                                      3b2                       1
# himachal                      HimachalPradesh   india         rainfall                                                                                                                                                                                                                                                                                                                 floods                  himalayas            mountains     travel           shimla                                                                                                                                                                                                                                                                                                                   manali               nature              himachali             pahadi             himachaltourism                                                                                                                                                                                                                                                                                                          travelphotography        incredibleindia                kullu                   uttarakhand        himachaldiaries                                                                                                                                                                                                                                                                                                         travelgram              instahimachal               love                 instagram             mandi                                                                                                                                                                                                                                                                                                                    kangra                        himachalpictures        kinnaur                   wanderlust          delhi                                                                                                                                                                                                                                                                                                                      chandigarh                1
# relógio                       bermuda           carteira      moletom                                                                                                                                                                                                                                                                                                                  óculos                  presente             pulseira      cueca            boné                                                                                                                                                                                                                                                                                                                     chaveiro             meia                acessoriosmasculinos  floods             camisetas                                                                                                                                                                                                                                                                                                                necessaire               mochila                        mala                    bebidasdestiladas  kitbar                                                                                                                                                                                                                                                                                                                  artigosmasculinos       mancare                     kitgourmet           gravata               cintodecouro                                                                                                                                                                                                                                                                                                             canivetes                     blusastricot            presentefloods            kitchurrasco        kitpizzaiolo                                                                                                                                                                                                                                                                                                               modamasculina             1
#                               inteligente       bermuda       sucesso                                                                                                                                                                                                                                                                                                                  carteira                motivação            moletom       foco             óculos                                                                                                                                                                                                                                                                                                                   linda                presente            felicidade            pulseira           marketingdigital                                                                                                                                                                                                                                                                                                         cueca                    princesa                       boné                    empreendedorismo   chaveiro                                                                                                                                                                                                                                                                                                                brasil                  meia                        amor                 acessoriosmasculinos  sabedoria                                                                                                                                                                                                                                                                                                                floods                        coaching                camisetas                 coach               necessaire                                                                                                                                                                                                                                                                                                                 mindset                   1
# savepunjab                    savepunjabwaters  farmers       sikhi                                                                                                                                                                                                                                                                                                                    floods                  sardari              waheguru      satnamwaheguruੴ  saveplanet                                                                                                                                                                                                                                                                                                               earth                universe            jupiter               moon               sunset                                                                                                                                                                                                                                                                                                                   stars                    edmonton                       amritsar                muktsar            patiala                                                                                                                                                                                                                                                                                                                 sikhism_feed            panjaab_info                historyofpanjab      followforfollowback   billionaire                                                                                                                                                                                                                                                                                                              dollars                       food                    justiceforsidhumoosewala  sidhumoosewala      pride                                                                                                                                                                                                                                                                                                                      latestpunjabisongs        1
# twitter                       polarization      maharastra    ir                                                                                                                                                                                                                                                                                                                       internationalrelations  skardu               dawn          dailydawn        newspaper                                                                                                                                                                                                                                                                                                                css                  pms                 LAW                   internationallaw   pakistan                                                                                                                                                                                                                                                                                                                 islamabad                articleoftheday                editorial               musabsaeed         learnwithmusabsaeed                                                                                                                                                                                                                                                                                                     democracy               politics                    monsoon              rain                  floods                                                                                                                                                                                                                                                                                                                   climatechange                 urbanflooding           disaster                  disastermanagement  india                                                                                                                                                                                                                                                                                                                      sindh                     1
# ഇരുട്ട്                       51797760478       FALSE         https://instagram.fphs4-1.fna.fbcdn.net/v/t51.2885-19/275808240_803546507270666_7342910892624618470_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fphs4-1.fna.fbcdn.net&_nc_cat=102&_nc_ohc=Xk4iFlFsavQAX9fD--F&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfBG2x7urRoUyPEZvafoi8gqHTLUpwQ8rpfOAcW0cp1fzg&oe=64B171FA&_nc_sid=2999b8   irutt_official          Rahul Kr             1424676327    FALSE            https://instagram.fphs4-1.fna.fbcdn.net/v/t51.2885-19/351508121_1904969696568525_4647682841225503925_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fphs4-1.fna.fbcdn.net&_nc_cat=109&_nc_ohc=paN9pS72e5oAX9S9ao3&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfBmxsSty8gwWwvSvA3uwnR-PuaEczlVCu1CP8NT3DnvYw&oe=64B2B03C&_nc_sid=2999b8  imrahulkr            🦋പ്രിയദളങ്ങള്‍ ✍️🦋  33505931581           FALSE              https://instagram.fphs4-1.fna.fbcdn.net/v/t51.2885-19/167274198_1836753996493773_4687296769391075312_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fphs4-1.fna.fbcdn.net&_nc_cat=109&_nc_ohc=v_iLcg-qkAUAX-USMHL&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfC2evddP3Js6QyQuy9B0UKzxc4YiscnZux_7ulco_MZ3A&oe=64B2A08D&_nc_sid=2999b8  priya_dhalangal          suhaina vazhakkad              37116606260             FALSE              https://instagram.fphs4-1.fna.fbcdn.net/v/t51.2885-19/343274335_748356060159204_7382772587921133498_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fphs4-1.fna.fbcdn.net&_nc_cat=100&_nc_ohc=cuMHhtWsBWIAX8spl6N&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfB7WO6vnPAooOayo95aoZ9IPvQH-cN3cGIqKCLcmuBpng&oe=64B0E436&_nc_sid=2999b8  suhaina_vazhakkad       കന്നാസും-കടലാസും ഒഫീഷ്യൽ 🔖  59322028035          FALSE                 https://instagram.fphs4-1.fna.fbcdn.net/v/t51.2885-19/353621097_228144343337524_394734827655031328_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fphs4-1.fna.fbcdn.net&_nc_cat=104&_nc_ohc=lDGUqu-U9KEAX_fu62r&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfACJwqBUQSJq4vvA3YHQqSIhk_NVn0lv-HJqOd4Wu9IIw&oe=64B29589&_nc_sid=2999b8    kannasum_kadalasum_official_  ഒരിടം                   36672473027               FALSE               https://instagram.fphs4-1.fna.fbcdn.net/v/t51.2885-19/101824399_3176748929056365_3839267947747055865_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.fphs4-1.fna.fbcdn.net&_nc_cat=109&_nc_ohc=ZyaP_y8Rr6YAX-v1ynH&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfBhUKalcTe-c7H5E7isQkHAdbJtOCxQCRhfoqR7QJqgug&oe=64B12D72&_nc_sid=2999b8    _oridam__                 1
# dtype: int64

# %%
# %pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.2)

# %%
import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
lemmatizer = WordNetLemmatizer()
for i in range(30):
    insta_posts[f'hashtags/{i}'] = insta_posts[f'hashtags/{i}'].apply(lambda x: '-' if isinstance(x, float) else x)
for i in range(30):
    insta_posts[f'hashtags/{i}'] = insta_posts[f'hashtags/{i}'].apply(lambda x: lemmatizer.lemmatize(x))
insta_posts
# Out:
#                                                caption                   id  \
# 0    30 Dead, Over 500 Stranded As Himachal Pradesh...  3144332908423964840
# 1    Places reserved by the government for people d...  3144333792524601542
# 2    Heavy rains lash the north. Heavy rains are fa...  3144332119812074456
# 3    The Yamuna in Delhi has exceeded the evacuatio...  3144323671550839497
# 4    DO FOLLOW @software_santha for more updates\n....  3144332111950871566
# ..                                                 ...                  ...
# 195  #road #flood #rain #Gurgaon #City #Citylife #G...                  NaN
# 196  Are you scared of thunder?⚡️\nIn frame @jha_re...                  NaN
# 197  There has been no rain in Patna for the last f...                  NaN
# 198  Rainy day in Kyoto🌂\nNinenzaka #Ninenzaka 🌧\n\...                  NaN
# 199  ɴᴀᴛᴜʀᴇ'ꜱ ᴄᴀɴᴠᴀꜱ!🎨🏍️\n\n 📸 @raj_shubham45\n#nat...                  NaN
#
#       locationId locationName    ownerFullName       ownerId    ownerUsername  \
# 0            NaN          NaN         PMNEWS24  5.503525e+10   pmnews24portal
# 1            NaN          NaN   Patiala Public  6.097173e+10    patialapublic
# 2            NaN          NaN  MyCityHyderabad  5.813841e+10   mycityhydmedia
# 3    213262633.0        Delhi      The insider  6.035445e+10  theinsider_news
# 4            NaN          NaN  Software_santha  3.466990e+10  software_santha
# ..           ...          ...              ...           ...              ...
# 195          NaN          NaN              NaN           NaN              NaN
# 196          NaN          NaN              NaN           NaN              NaN
# 197          NaN          NaN              NaN           NaN              NaN
# 198          NaN          NaN              NaN           NaN              NaN
# 199          NaN          NaN              NaN           NaN              NaN
#
#                     timestamp   hashtags/0      hashtags/1  ...  hashtags/20  \
# 0    2023-07-11T05:35:13.000Z     pmnews24           flood  ...            -
# 1    2023-07-11T05:36:59.000Z      patiala           flood  ...            -
# 2    2023-07-11T05:33:39.000Z  NorthStates  mycityhydmedia  ...  pedestrains
# 3    2023-07-11T05:16:52.000Z        flood        flooding  ...  remediation
# 4    2023-07-11T05:33:38.000Z         news           flood  ...            -
# ..                        ...          ...             ...  ...          ...
# 195                       NaN            -               -  ...            -
# 196                       NaN            -               -  ...            -
# 197                       NaN            -               -  ...            -
# 198                       NaN            -               -  ...            -
# 199                       NaN            -               -  ...            -
#
#          hashtags/21  hashtags/22 hashtags/23 hashtags/24 hashtags/25  \
# 0                  -            -           -           -           -
# 1                  -            -           -           -           -
# 2         cropfields  waterlogged    Redalert         IMD  Telugunews
# 3    watermitigation        flood     weather       river   hurricane
# 4                  -            -           -           -           -
# ..               ...          ...         ...         ...         ...
# 195                -            -           -           -           -
# 196                -            -           -           -           -
# 197                -            -           -           -           -
# 198                -            -           -           -           -
# 199                -            -           -           -           -
#
#     hashtags/26 hashtags/27 hashtags/28  hashtags/29
# 0             -           -           -            -
# 1             -           -           -            -
# 2        update           -           -            -
# 3        kerala        life       india  moldremoval
# 4             -           -           -            -
# ..          ...         ...         ...          ...
# 195           -           -           -            -
# 196           -           -           -            -
# 197           -           -           -            -
# 198           -           -           -            -
# 199           -           -           -            -
#
# [200 rows x 38 columns]

# %%
insta_posts.loc[:, 'hashtags/0':].value_counts()
# Out:
# hashtags/0        hashtags/1    hashtags/2      hashtags/3                                                                                                                                                                                                                                                                                                              hashtags/4    hashtags/5        hashtags/6    hashtags/7       hashtags/8                                                                                                                                                                                                                                                                                                              hashtags/9         hashtags/10          hashtags/11  hashtags/12  hashtags/13                                                                                                                                                                                                                                                                                                           hashtags/14   hashtags/15       hashtags/16             hashtags/17                   hashtags/18                                                                                                                                                                                                                                                                                                            hashtags/19        hashtags/20    hashtags/21      hashtags/22  hashtags/23  hashtags/24      hashtags/25  hashtags/26  hashtags/27  hashtags/28  hashtags/29
# -                 -             -               -                                                                                                                                                                                                                                                                                                                       -             -                 -             -                -                                                                                                                                                                                                                                                                                                                       -                  -                    -            -            -                                                                                                                                                                                                                                                                                                                     -             -                 -                       -                             -                                                                                                                                                                                                                                                                                                                      -                  -              -                -            -            -                -            -            -            -            -              92
# flood             flooding      waterdamage     water                                                                                                                                                                                                                                                                                                                   rain          nature            restoration   insurance        mold                                                                                                                                                                                                                                                                                                                    fire               flooddamage          storm        firedamage   disaster                                                                                                                                                                                                                                                                                                              photography   climatechange     waterdamagerestoration  propertydamage                covid                                                                                                                                                                                                                                                                                                                  moldremediation    remediation    watermitigation  flood        weather      river            hurricane    kerala       life         india        moldremoval     3
# patiala           punjab        flood           puinstants                                                                                                                                                                                                                                                                                                              wmk           waheguru          human         humanity         showhumanity                                                                                                                                                                                                                                                                                                            insta              instagood            saveanimals  savedogs     doglover                                                                                                                                                                                                                                                                                                              narendramodi  indiangovernment  disaster                ministryofdisastermanagement  disastermanagement                                                                                                                                                                                                                                                                                                     haryanagovernment  unitedkingdom  unitedstates     usa          canada       dubaigovernment  -            -            -            -            -               2
# parvasisahayta    parvasinews   news            flood                                                                                                                                                                                                                                                                                                                   punjab        help              khalasa       khalasaaid       -                                                                                                                                                                                                                                                                                                                       -                  -                    -            -            -                                                                                                                                                                                                                                                                                                                     -             -                 -                       -                             -                                                                                                                                                                                                                                                                                                                      -                  -              -                -            -            -                -            -            -            -            -               1
# nofilter          ambalafloods  himachalfloods  haryanafloods                                                                                                                                                                                                                                                                                                           flood         northindiafloods  royalenfield  thunderbird350x  -                                                                                                                                                                                                                                                                                                                       -                  -                    -            -            -                                                                                                                                                                                                                                                                                                                     -             -                 -                       -                             -                                                                                                                                                                                                                                                                                                                      -                  -              -                -            -            -                -            -            -            -            -               1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ..
# disaster          safety        disasterrelief  disastermanagement                                                                                                                                                                                                                                                                                                      flashflood    emergency         flood         landslide        himalayanfloods                                                                                                                                                                                                                                                                                                         climatechange      extremeweather       india        himachal     uttrakhand                                                                                                                                                                                                                                                                                                            kullu         manali            baddi                   parwanoo                      shimla                                                                                                                                                                                                                                                                                                                 solan              satluj         yamuna           punjab       -            -                -            -            -            -            -               1
# delhifood         flood         yamuna          yamunariver                                                                                                                                                                                                                                                                                                             news          india             -             -                -                                                                                                                                                                                                                                                                                                                       -                  -                    -            -            -                                                                                                                                                                                                                                                                                                                     -             -                 -                       -                             -                                                                                                                                                                                                                                                                                                                      -                  -              -                -            -            -                -            -            -            -            -               1
# delhi             dilli         monsoon         havoc                                                                                                                                                                                                                                                                                                                   devastation   flood             water         rainyday         newdelhi                                                                                                                                                                                                                                                                                                                gurgaon            -                    -            -            -                                                                                                                                                                                                                                                                                                                     -             -                 -                       -                             -                                                                                                                                                                                                                                                                                                                      -                  -              -                -            -            -                -            -            -            -            -               1
# dead              Floods        Heavy           india                                                                                                                                                                                                                                                                                                                   -             -                 -             -                -                                                                                                                                                                                                                                                                                                                       -                  -                    -            -            -                                                                                                                                                                                                                                                                                                                     -             -                 -                       -                             -                                                                                                                                                                                                                                                                                                                      -                  -              -                -            -            -                -            -            -            -            -               1
# 🌸 ZARA OUTFITS 🌸  2141812134    FALSE           https://instagram.flex2-1.fna.fbcdn.net/v/t51.2885-19/32407013_1401657769980438_1433140074534404096_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.flex2-1.fna.fbcdn.net&_nc_cat=106&_nc_ohc=qkqE6P2sezEAX--aRU-&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfBOAM9S2dhwuxRQ_dkYvoIuB2wPYPG_kGLkIOp72I5-aw&oe=64B21C65&_nc_sid=2999b8  zara.outfits  TajMadikeri       8664783805    FALSE            https://instagram.flex2-1.fna.fbcdn.net/v/t51.2885-19/73420148_2603955193032077_6904476153877102592_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.flex2-1.fna.fbcdn.net&_nc_cat=105&_nc_ohc=1n-cORl-PqQAX93jbhW&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfAEpTNn03av8gsfDO4LKGEUlFE90CeKrf6RSmJXZmR0XA&oe=64B1A21D&_nc_sid=2999b8  tajmadikeriresort  ZARA INDIA BLOGGERS  15314236752  FALSE        https://instagram.flex2-1.fna.fbcdn.net/v/t51.2885-19/65300424_416324045628298_893159662046674944_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.flex2-1.fna.fbcdn.net&_nc_cat=110&_nc_ohc=oRrbFxg7XUwAX9Zs2VF&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfD3aoQB2F1v0TwFBtGNjg6ORU3Wv2-NCCiFqJMUqa5Ytw&oe=64B2BABA&_nc_sid=2999b8  zaraindia_    Zara              5705738126              FALSE                         https://instagram.flex2-1.fna.fbcdn.net/v/t51.2885-19/41421651_294890541103370_8551688402150359040_n.jpg?stp=dst-jpg_s150x150&_nc_ht=instagram.flex2-1.fna.fbcdn.net&_nc_cat=102&_nc_ohc=u_wUH6_ik-gAX8gAJ4v&edm=AP_V10EBAAAA&ccb=7-5&oh=00_AfDBrQ5C7OegKBeB_Papd3r6_Z6tN7yzbHI-JFNsyWudnQ&oe=64B0F305&_nc_sid=2999b8  _zaraindia         -              -                -            -            -                -            -            -            -            -               1
# Length: 106, dtype: int64

# %%
insta_posts['caption'] = insta_posts.caption.apply(lambda x: lemmatizer.lemmatize(x))

# %%
insta_posts
# Out:
#                                                caption                   id  \
# 0    30 Dead, Over 500 Stranded As Himachal Pradesh...  3144332908423964840
# 1    Places reserved by the government for people d...  3144333792524601542
# 2    Heavy rains lash the north. Heavy rains are fa...  3144332119812074456
# 3    The Yamuna in Delhi has exceeded the evacuatio...  3144323671550839497
# 4    DO FOLLOW @software_santha for more updates\n....  3144332111950871566
# ..                                                 ...                  ...
# 195  #road #flood #rain #Gurgaon #City #Citylife #G...                  NaN
# 196  Are you scared of thunder?⚡️\nIn frame @jha_re...                  NaN
# 197  There has been no rain in Patna for the last f...                  NaN
# 198  Rainy day in Kyoto🌂\nNinenzaka #Ninenzaka 🌧\n\...                  NaN
# 199  ɴᴀᴛᴜʀᴇ'ꜱ ᴄᴀɴᴠᴀꜱ!🎨🏍️\n\n 📸 @raj_shubham45\n#nat...                  NaN
#
#       locationId locationName    ownerFullName       ownerId    ownerUsername  \
# 0            NaN          NaN         PMNEWS24  5.503525e+10   pmnews24portal
# 1            NaN          NaN   Patiala Public  6.097173e+10    patialapublic
# 2            NaN          NaN  MyCityHyderabad  5.813841e+10   mycityhydmedia
# 3    213262633.0        Delhi      The insider  6.035445e+10  theinsider_news
# 4            NaN          NaN  Software_santha  3.466990e+10  software_santha
# ..           ...          ...              ...           ...              ...
# 195          NaN          NaN              NaN           NaN              NaN
# 196          NaN          NaN              NaN           NaN              NaN
# 197          NaN          NaN              NaN           NaN              NaN
# 198          NaN          NaN              NaN           NaN              NaN
# 199          NaN          NaN              NaN           NaN              NaN
#
#                     timestamp   hashtags/0      hashtags/1  ...  hashtags/20  \
# 0    2023-07-11T05:35:13.000Z     pmnews24           flood  ...            -
# 1    2023-07-11T05:36:59.000Z      patiala           flood  ...            -
# 2    2023-07-11T05:33:39.000Z  NorthStates  mycityhydmedia  ...  pedestrains
# 3    2023-07-11T05:16:52.000Z        flood        flooding  ...  remediation
# 4    2023-07-11T05:33:38.000Z         news           flood  ...            -
# ..                        ...          ...             ...  ...          ...
# 195                       NaN            -               -  ...            -
# 196                       NaN            -               -  ...            -
# 197                       NaN            -               -  ...            -
# 198                       NaN            -               -  ...            -
# 199                       NaN            -               -  ...            -
#
#          hashtags/21  hashtags/22 hashtags/23 hashtags/24 hashtags/25  \
# 0                  -            -           -           -           -
# 1                  -            -           -           -           -
# 2         cropfields  waterlogged    Redalert         IMD  Telugunews
# 3    watermitigation        flood     weather       river   hurricane
# 4                  -            -           -           -           -
# ..               ...          ...         ...         ...         ...
# 195                -            -           -           -           -
# 196                -            -           -           -           -
# 197                -            -           -           -           -
# 198                -            -           -           -           -
# 199                -            -           -           -           -
#
#     hashtags/26 hashtags/27 hashtags/28  hashtags/29
# 0             -           -           -            -
# 1             -           -           -            -
# 2        update           -           -            -
# 3        kerala        life       india  moldremoval
# 4             -           -           -            -
# ..          ...         ...         ...          ...
# 195           -           -           -            -
# 196           -           -           -            -
# 197           -           -           -            -
# 198           -           -           -            -
# 199           -           -           -            -
#
# [200 rows x 38 columns]

# %%
insta_post_nlp = insta_posts[insta_posts['caption'].str.contains('flood', regex=True, na=False)]
insta_post_nlp
# Out:
#                                                caption                   id  \
# 0    30 Dead, Over 500 Stranded As Himachal Pradesh...  3144332908423964840
# 1    Places reserved by the government for people d...  3144333792524601542
# 2    Heavy rains lash the north. Heavy rains are fa...  3144332119812074456
# 3    The Yamuna in Delhi has exceeded the evacuatio...  3144323671550839497
# 4    DO FOLLOW @software_santha for more updates\n....  3144332111950871566
# ..                                                 ...                  ...
# 140  Record rainfall in Indian capital – more than ...                  NaN
# 158  Patiala District\nWater level status\n#patiala...                  NaN
# 167  The water level of Yamuna in Delhi has touched...                  NaN
# 168  Rain\nSomething that makes ahemdabad flooded w...                  NaN
# 195  #road #flood #rain #Gurgaon #City #Citylife #G...                  NaN
#
#       locationId locationName    ownerFullName       ownerId    ownerUsername  \
# 0            NaN          NaN         PMNEWS24  5.503525e+10   pmnews24portal
# 1            NaN          NaN   Patiala Public  6.097173e+10    patialapublic
# 2            NaN          NaN  MyCityHyderabad  5.813841e+10   mycityhydmedia
# 3    213262633.0        Delhi      The insider  6.035445e+10  theinsider_news
# 4            NaN          NaN  Software_santha  3.466990e+10  software_santha
# ..           ...          ...              ...           ...              ...
# 140          NaN          NaN              NaN           NaN              NaN
# 158          NaN          NaN              NaN           NaN              NaN
# 167          NaN          NaN              NaN           NaN              NaN
# 168          NaN          NaN              NaN           NaN              NaN
# 195          NaN          NaN              NaN           NaN              NaN
#
#                     timestamp   hashtags/0      hashtags/1  ...  hashtags/20  \
# 0    2023-07-11T05:35:13.000Z     pmnews24           flood  ...            -
# 1    2023-07-11T05:36:59.000Z      patiala           flood  ...            -
# 2    2023-07-11T05:33:39.000Z  NorthStates  mycityhydmedia  ...  pedestrains
# 3    2023-07-11T05:16:52.000Z        flood        flooding  ...  remediation
# 4    2023-07-11T05:33:38.000Z         news           flood  ...            -
# ..                        ...          ...             ...  ...          ...
# 140                       NaN            -               -  ...            -
# 158                       NaN            -               -  ...            -
# 167                       NaN            -               -  ...            -
# 168                       NaN            -               -  ...            -
# 195                       NaN            -               -  ...            -
#
#          hashtags/21  hashtags/22 hashtags/23 hashtags/24 hashtags/25  \
# 0                  -            -           -           -           -
# 1                  -            -           -           -           -
# 2         cropfields  waterlogged    Redalert         IMD  Telugunews
# 3    watermitigation        flood     weather       river   hurricane
# 4                  -            -           -           -           -
# ..               ...          ...         ...         ...         ...
# 140                -            -           -           -           -
# 158                -            -           -           -           -
# 167                -            -           -           -           -
# 168                -            -           -           -           -
# 195                -            -           -           -           -
#
#     hashtags/26 hashtags/27 hashtags/28  hashtags/29
# 0             -           -           -            -
# 1             -           -           -            -
# 2        update           -           -            -
# 3        kerala        life       india  moldremoval
# 4             -           -           -            -
# ..          ...         ...         ...          ...
# 140           -           -           -            -
# 158           -           -           -            -
# 167           -           -           -            -
# 168           -           -           -            -
# 195           -           -           -            -
#
# [96 rows x 38 columns]

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

eng_stopwords = stopwords.words('english')
insta_post_nlp['caption'] = insta_post_nlp['caption'].apply(lambda x: ' '.join([word for word in x.split() if word not in eng_stopwords]))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# <ipython-input-17-c786f24d0c89>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insta_post_nlp['caption'] = insta_post_nlp['caption'].apply(lambda x: ' '.join([word for word in x.split() if word not in eng_stopwords]))

# %%
import string

def remove_punctuations(text):
    for punctuation in string.punctuation: text = text.replace(punctuation, '')
    return text

insta_post_nlp['caption'] = insta_post_nlp['caption'].apply(lambda x: remove_punctuations(x))
# Out:
# <ipython-input-18-1915ceca719a>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insta_post_nlp['caption'] = insta_post_nlp['caption'].apply(lambda x: remove_punctuations(x))

# %%
insta_post_nlp['caption'] = insta_post_nlp['caption'].apply(lambda x: x.split())
# Out:
# <ipython-input-19-42582b377a2f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insta_post_nlp['caption'] = insta_post_nlp['caption'].apply(lambda x: x.split())

# %%
import re

def lemmatize(caption):
    token_list = []
    # caption = re.sub(r'[^a-zA-Z0-9\s,;.!?"\':-]', '', caption)
    for word in caption:
        token_list.append(lemmatizer.lemmatize(word).lower())
    return token_list

insta_post_nlp['caption'] = insta_post_nlp['caption'].apply(lambda x: lemmatize(x))

insta_post_nlp
# Out:
# <ipython-input-20-9aafd223c7e2>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   insta_post_nlp['caption'] = insta_post_nlp['caption'].apply(lambda x: lemmatize(x))
#                                                caption                   id  \
# 0    [30, dead, over, 500, stranded, as, himachal, ...  3144332908423964840
# 1    [places, reserved, government, people, displac...  3144333792524601542
# 2    [heavy, rain, lash, north, heavy, rain, fallin...  3144332119812074456
# 3    [the, yamuna, delhi, exceeded, evacuation, mar...  3144323671550839497
# 4    [do, follow, softwaresantha, update, news, flo...  3144332111950871566
# ..                                                 ...                  ...
# 140  [record, rainfall, indian, capital, –, 50, dea...                  NaN
# 158  [patiala, district, water, level, status, pati...                  NaN
# 167  [the, water, level, yamuna, delhi, touched, 26...                  NaN
# 168  [rain, something, make, ahemdabad, flooded, lo...                  NaN
# 195  [road, flood, rain, gurgaon, city, citylife, g...                  NaN
#
#       locationId locationName    ownerFullName       ownerId    ownerUsername  \
# 0            NaN          NaN         PMNEWS24  5.503525e+10   pmnews24portal
# 1            NaN          NaN   Patiala Public  6.097173e+10    patialapublic
# 2            NaN          NaN  MyCityHyderabad  5.813841e+10   mycityhydmedia
# 3    213262633.0        Delhi      The insider  6.035445e+10  theinsider_news
# 4            NaN          NaN  Software_santha  3.466990e+10  software_santha
# ..           ...          ...              ...           ...              ...
# 140          NaN          NaN              NaN           NaN              NaN
# 158          NaN          NaN              NaN           NaN              NaN
# 167          NaN          NaN              NaN           NaN              NaN
# 168          NaN          NaN              NaN           NaN              NaN
# 195          NaN          NaN              NaN           NaN              NaN
#
#                     timestamp   hashtags/0      hashtags/1  ...  hashtags/20  \
# 0    2023-07-11T05:35:13.000Z     pmnews24           flood  ...            -
# 1    2023-07-11T05:36:59.000Z      patiala           flood  ...            -
# 2    2023-07-11T05:33:39.000Z  NorthStates  mycityhydmedia  ...  pedestrains
# 3    2023-07-11T05:16:52.000Z        flood        flooding  ...  remediation
# 4    2023-07-11T05:33:38.000Z         news           flood  ...            -
# ..                        ...          ...             ...  ...          ...
# 140                       NaN            -               -  ...            -
# 158                       NaN            -               -  ...            -
# 167                       NaN            -               -  ...            -
# 168                       NaN            -               -  ...            -
# 195                       NaN            -               -  ...            -
#
#          hashtags/21  hashtags/22 hashtags/23 hashtags/24 hashtags/25  \
# 0                  -            -           -           -           -
# 1                  -            -           -           -           -
# 2         cropfields  waterlogged    Redalert         IMD  Telugunews
# 3    watermitigation        flood     weather       river   hurricane
# 4                  -            -           -           -           -
# ..               ...          ...         ...         ...         ...
# 140                -            -           -           -           -
# 158                -            -           -           -           -
# 167                -            -           -           -           -
# 168                -            -           -           -           -
# 195                -            -           -           -           -
#
#     hashtags/26 hashtags/27 hashtags/28  hashtags/29
# 0             -           -           -            -
# 1             -           -           -            -
# 2        update           -           -            -
# 3        kerala        life       india  moldremoval
# 4             -           -           -            -
# ..          ...         ...         ...          ...
# 140           -           -           -            -
# 158           -           -           -            -
# 167           -           -           -            -
# 168           -           -           -            -
# 195           -           -           -            -
#
# [96 rows x 38 columns]

# %%
# %pip install -q transformers

# %%
from transformers import pipeline

# %%
sentiment_pipeline = pipeline('sentiment-analysis')
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]

# %%
insta_posts['caption'] = insta_posts['caption'].apply(lambda x: str(x))

# %%
caption_sentiment_list = []
for caption in insta_posts['caption']:
    caption = str(caption)
    if len(caption) >512: caption = caption[:512]
    caption_sentiment_list.append(caption)

# %%
sentiment_posts_caption = sentiment_pipeline(caption_sentiment_list)

# %%
negative_sentiment = sum(sentiment['label'] == 'NEGATIVE' for sentiment in sentiment_posts_caption)
positive_sentiment = sum(sentiment['label'] == 'POSITIVE' for sentiment in sentiment_posts_caption)

sentiment_df = pd.DataFrame(sentiment_posts_caption)

# %%
px.bar(sentiment_df, x='label', y='score', color='score')

# %%
sentiment_caption_graph = []
for caption in insta_post_nlp['caption']:
    for word in caption: sentiment_caption_graph.append(word)
sentiment_caption_graph
# Out:
# ['30',
#  'dead',
#  'over',
#  '500',
#  'stranded',
#  'as',
#  'himachal',
#  'pradesh',
#  'faces',
#  'rain',
#  'mayhem',
#  'pmnews24',
#  'flood',
#  'rainmayhem',
#  'himachalpradesh',
#  'redalert',
#  'danger',
#  'latestnews',
#  'todaynews',
#  'trendngnews',
#  'dead',
#  'propertyloss',
#  'places',
#  'reserved',
#  'government',
#  'people',
#  'displaced',
#  'due',
#  'flood',
#  'patiala',
#  'flood',
#  'punjab',
#  'heavy',
#  'rain',
#  'lash',
#  'north',
#  'heavy',
#  'rain',
#  'falling',
#  'delhi',
#  'haryana',
#  'punjab',
#  'rajasthan',
#  'himachal',
#  'uttarakhand',
#  'jammu',
#  'kashmir',
#  'officials',
#  'said',
#  '37',
#  'people',
#  'died',
#  'different',
#  'incident',
#  'far',
#  'due',
#  'heavy',
#  'rain',
#  'northstates',
#  'mycityhydmedia',
#  'himachalpradesh',
#  'latestnews',
#  'newstoday',
#  'heavyrains',
#  'updatesalottoday',
#  'uttarakhand',
#  'jammuandkashmir',
#  'uttarpradesh',
#  'rajasthan',
#  'punjab',
#  'delhirains',
#  'updatenewstoday',
#  'todaynews',
#  'todayspecial',
#  'death',
#  'underpass',
#  'flood',
#  'commuter',
#  'pedestrains',
#  'cropfields',
#  'waterlogged',
#  'redalert',
#  'imd',
#  'telugunews',
#  'update',
#  'the',
#  'yamuna',
#  'delhi',
#  'exceeded',
#  'evacuation',
#  'mark',
#  '206',
#  'metre',
#  'prompting',
#  'relocation',
#  'people',
#  'residing',
#  'floodprone',
#  'area',
#  'safer',
#  'location',
#  'official',
#  'said',
#  'tuesday',
#  'the',
#  'river',
#  'crossed',
#  'danger',
#  'mark',
#  '20533',
#  'metre',
#  'delhi',
#  'monday',
#  'evening',
#  'much',
#  'earlier',
#  'anticipated',
#  'according',
#  'central',
#  'water',
#  'commissions',
#  'cwc',
#  'floodmonitoring',
#  'portal',
#  'water',
#  'level',
#  'old',
#  'railway',
#  'bridge',
#  'rose',
#  '20628',
#  'metre',
#  '6',
#  'tuesday',
#  'haryana',
#  'releasing',
#  'water',
#  'river',
#  'hathnikund',
#  'barrage',
#  'yamunanagar',
#  'flood',
#  'flooding',
#  'waterdamage',
#  'water',
#  'rain',
#  'nature',
#  'restoration',
#  'insurance',
#  'mold',
#  'fire',
#  'flooddamage',
#  'storm',
#  'firedamage',
#  'disaster',
#  'photography',
#  'climatechange',
#  'waterdamagerestoration',
#  'propertydamage',
#  'covid',
#  'moldremediation',
#  'remediation',
#  'watermitigation',
#  'flood',
#  'weather',
#  'river',
#  'hurricane',
#  'kerala',
#  'life',
#  'india',
#  'moldremoval',
#  'do',
#  'follow',
#  'softwaresantha',
#  'update',
#  'news',
#  'flood',
#  'telangana',
#  'hyderabad',
#  'india',
#  'waranagal',
#  'karimnagar',
#  'update',
#  'instadaily',
#  'trending',
#  'trendingnow',
#  'meme',
#  'memedaily',
#  'you',
#  'beauty',
#  '💜',
#  'nofilter',
#  'ambalafloods',
#  'himachalfloods',
#  'haryanafloods',
#  'flood',
#  'northindiafloods',
#  'royalenfield',
#  'thunderbird350x',
#  'what',
#  '😦',
#  'make',
#  'south',
#  'asia',
#  '🌏',
#  'vulnerable',
#  'climate',
#  'change',
#  'content',
#  'source',
#  'by',
#  'usaid',
#  'siddiqui',
#  'read',
#  '👉',
#  'httpswwwaljazeeracomnews202378whatmakessouthasiasovulnerabletoclimatechange',
#  'climatechange',
#  'flood',
#  'storm',
#  'foodinsecurity',
#  'rain',
#  'the',
#  'situation',
#  'intense',
#  'worrisome',
#  'as',
#  'distressing',
#  'video',
#  'building',
#  'bridge',
#  'collapsing',
#  'go',
#  'viral',
#  'tour',
#  'operator',
#  'strongly',
#  'recommend',
#  'everyone',
#  'refrain',
#  'undertaking',
#  'nonessential',
#  'travel',
#  'hill',
#  'tap',
#  'link',
#  'story',
#  'read',
#  'karishmatanna',
#  'adilnargolwala',
#  'flood',
#  'rain',
#  'monsoon',
#  'himachalpradesh',
#  'shimla',
#  'chandigarh',
#  'ambala',
#  'riverbeas',
#  'manali',
#  'dharamshala',
#  'amritsar',
#  'delhi',
#  'travel',
#  'travelplans',
#  'delhitimes',
#  'actor',
#  'ruslaan',
#  'mumtaz',
#  'stranded',
#  'floodstricken',
#  'manali',
#  'share',
#  'clip',
#  'destroyed',
#  'road',
#  'manali',
#  'quaint',
#  'hill',
#  'station',
#  'himachal',
#  'pradesh',
#  'currently',
#  'besieged',
#  'devastating',
#  'flood',
#  'the',
#  'scenic',
#  'resort',
#  'town',
#  'one',
#  'seven',
#  'district',
#  'himachal',
#  'pradesh',
#  'havocked',
#  'heavy',
#  'rain',
#  'bollywood',
#  'actor',
#  'ruslaan',
#  'mumtaz',
#  'currently',
#  'shooting',
#  'film',
#  'hill',
#  'station',
#  'one',
#  'many',
#  'tourist',
#  'left',
#  'stranded',
#  'taking',
#  'instagram',
#  '‘mera',
#  'pehla',
#  'pehla',
#  'pyaar’',
#  'star',
#  'told',
#  'fan',
#  'stuck',
#  'manali',
#  'due',
#  'flood',
#  'road',
#  'connected',
#  'manali',
#  'chandigarh',
#  'badly',
#  'damaged',
#  'gushing',
#  'water',
#  'to',
#  'know',
#  'more',
#  'click',
#  'link',
#  'bio',
#  'ruslaanmumtaz',
#  'flood',
#  'india',
#  'northern',
#  'india',
#  'battered',
#  'heavy',
#  'rain',
#  'causing',
#  'flooding',
#  'landslide',
#  'closed',
#  'school',
#  'left',
#  'least',
#  '22',
#  'people',
#  'dead',
#  'according',
#  'official',
#  'local',
#  'medium',
#  'the',
#  '“intense',
#  'rainfall',
#  'spell”',
#  'region',
#  'forecast',
#  'continue',
#  'monday',
#  '“extremely',
#  'heavy',
#  'rainfall”',
#  'expected',
#  'northeastern',
#  'eastern',
#  'region',
#  'country',
#  'week',
#  'according',
#  'weather',
#  'briefing',
#  'india',
#  'meteorological',
#  'department',
#  'india',
#  'floods',
#  'monsoon',
#  'iwk',
#  'the',
#  'water',
#  'level',
#  'yamuna',
#  'delhi',
#  'breached',
#  'danger',
#  'mark',
#  '20533',
#  'metre',
#  'hovering',
#  '20632',
#  'mere',
#  '8',
#  'today',
#  'triggering',
#  'high',
#  'alert',
#  'according',
#  'central',
#  'water',
#  'commission',
#  'officials',
#  'said',
#  'river',
#  'breached',
#  'danger',
#  'mark',
#  'earlier',
#  'expected',
#  'with',
#  'haryana',
#  'releasing',
#  'water',
#  'today',
#  'yamuna',
#  'swell',
#  'next',
#  '24',
#  'hour',
#  'said',
#  'pc',
#  'ndtv',
#  'follow',
#  'pinkvilla',
#  'delhifood',
#  'flood',
#  'yamuna',
#  'yamunariver',
#  'news',
#  'india',
#  'flood',
#  'flood',
#  'monsoon',
#  'update',
#  'dedicated',
#  'mc',
#  'team',
#  'regularly',
#  'monitoring',
#  'water',
#  'level',
#  'buddha',
#  'nullah',
#  'teams',
#  'also',
#  'deputed',
#  'avoid',
#  'waterlogging',
#  'surrounding',
#  'area',
#  'over',
#  '200',
#  'employee',
#  'mc',
#  'duty',
#  'different',
#  'point',
#  'nullah',
#  'in',
#  'case',
#  'emergency',
#  'resident',
#  'contact',
#  '247',
#  'flood',
#  'control',
#  'room',
#  'mc',
#  '01612749120',
#  '1000thingsinludhiana',
#  'ludhiana',
#  'flood',
#  'punjab',
#  'floodhelpline',
#  'chandigarhblogger',
#  'jalandhar',
#  'patiala',
#  'the',
#  'visuals',
#  'coming',
#  'rain',
#  'north',
#  'india',
#  'tragic',
#  'reminder',
#  'become',
#  'new',
#  'normal',
#  'age',
#  'climate',
#  'change',
#  'our',
#  'thought',
#  'impacted',
#  '📸',
#  'afpgetty',
#  'image',
#  'flood',
#  'india',
#  'climatechange',
#  'globalwarming',
#  'newnormal',
#  'himachal',
#  'delhi',
#  'punjab',
#  'river',
#  'greenpeace',
#  'greenpeaceindia',
#  'indianfloods',
#  'indianflood',
#  'flood',
#  'flooding',
#  'waterdamage',
#  'water',
#  'rain',
#  'nature',
#  'restoration',
#  'insurance',
#  'mold',
#  'fire',
#  'flooddamage',
#  'storm',
#  'firedamage',
#  'disaster',
#  'photography',
#  'climatechange',
#  'waterdamagerestoration',
#  'propertydamage',
#  'covid',
#  'moldremediation',
#  'remediation',
#  'watermitigation',
#  'flood',
#  'weather',
#  'river',
#  'hurricane',
#  'kerala',
#  'life',
#  'india',
#  'moldremoval',
#  'prayforpunjab',
#  'punjab',
#  'wmk',
#  'flood',
#  'chalo',
#  'kuch',
#  'toh',
#  'advantage',
#  'hai…',
#  'wfhlife',
#  'corporatelife',
#  'workfromhomejob',
#  'delhimemes',
#  'bangalorememes',
#  'mumbaimemes',
#  'flood',
#  'rainlover',
#  'rainstorm',
#  'workfromoffice',
#  'officejokes',
#  'officememes',
#  'corporatememes',
#  'wfhstyle',
#  'wfhmemes',
#  'wfhtips',
#  'wfhjobs',
#  'wfhproblems',
#  'wfhdesk',
#  'wfhmom',
#  'in',
#  'delhi',
#  'yamuna',
#  'breached',
#  'danger',
#  'mark',
#  '20533',
#  'metre',
#  'late',
#  'last',
#  'evening',
#  'shot',
#  '20632',
#  'morning',
#  'haryana',
#  'released',
#  'water',
#  'river',
#  'hathnikund',
#  'barrage',
#  'officials',
#  'said',
#  'river',
#  'breached',
#  'danger',
#  'mark',
#  'earlier',
#  'expected',
#  'with',
#  'haryana',
#  'releasing',
#  'water',
#  'today',
#  'yamuna',
#  'swell',
#  'next',
#  '24',
#  'hour',
#  'said',
#  'news',
#  'source',
#  'ndtv',
#  '1000thingsinindia',
#  'delhidiaries',
#  'delhigram',
#  'sodelhi',
#  'flood',
#  'indiatravel',
#  'gurugram',
#  'noidagram',
#  'ye',
#  'mausam',
#  'ka',
#  'jadoo',
#  'hai',
#  'mitwaa…😍😍😍',
#  '📸',
#  'sinhamanas',
#  'monsoonseason',
#  'monsoon☔',
#  'monsoondiaries☔',
#  'hillsong',
#  'flood',
#  'greener',
#  'greenery🌿',
#  'maharashtramaza',
#  'maharastra',
#  'mumbairains',
#  'aurangabadbeats',
#  'aurangabadbeats',
#  'vit',
#  'gingerhotels',
#  'jyotirlingadarshan',
#  'mahadev',
#  'saavan',
#  'sravan',
#  'scenicview',
#  'beautybloggers',
#  'solotravel',
#  'travelgram',
#  'one',
#  'figure',
#  'praise',
#  'god',
#  '🤲🏻',
#  'panjaabinfo',
#  'please',
#  'follow',
#  '🙏🏻',
#  'savepunjab',
#  'savepunjabwaters',
#  'farmer',
#  'sikhi',
#  'flood',
#  'sardari',
#  'waheguru',
#  'satnamwaheguru',
#  'saveplanet',
#  'earth',
#  'universe',
#  'jupiter',
#  'moon',
#  'sunset',
#  'star',
#  'edmonton',
#  'amritsar',
#  'muktsar',
#  'patiala',
#  'sikhismfeed',
#  'panjaabinfo',
#  'historyofpanjab',
#  'followforfollowback',
#  'billionaire',
#  'dollar',
#  'food',
#  'justiceforsidhumoosewala',
#  'sidhumoosewala',
#  'pride',
#  'latestpunjabisongs',
#  'torrential',
#  'rain',
#  'across',
#  'northern',
#  'india',
#  'killed',
#  'least',
#  '22',
#  'people',
#  'well',
#  'causing',
#  'landslide',
#  'flash',
#  'flood',
#  'region',
#  'authority',
#  'local',
#  'medium',
#  'said',
#  'monday',
#  'schools',
#  'new',
#  'delhi',
#  'closed',
#  'heavy',
#  'rain',
#  'lashed',
#  'national',
#  'capital',
#  'weekend',
#  'authority',
#  'himalayan',
#  'state',
#  'himachal',
#  'pradesh',
#  'uttarakhand',
#  'asked',
#  'people',
#  'venture',
#  'home',
#  'unless',
#  'necessary',
#  'at',
#  'least',
#  '22',
#  'people',
#  'died',
#  'flood',
#  'landslide',
#  'northern',
#  'state',
#  'himachal',
#  'pradesh',
#  'uttarakhand',
#  'uttar',
#  'pradesh',
#  'jammu',
#  'kashmir',
#  'punjab',
#  'sunday',
#  'times',
#  'india',
#  'newspaper',
#  'reported',
#  'in',
#  'northern',
#  'state',
#  'himachal',
#  'pradesh',
#  'flash',
#  'flood',
#  'weekend',
#  'brought',
#  'bridge',
#  'swept',
#  'away',
#  'several',
#  'hutment',
#  'authorities',
#  'used',
#  'helicopter',
#  'rescue',
#  'people',
#  'stranded',
#  'road',
#  'bridge',
#  'rain',
#  'footage',
#  'reuters',
#  'partner',
#  'ani',
#  'showed',
#  'for',
#  'news',
#  'update',
#  'visit',
#  'wwwqatardaycom',
#  'india',
#  'rain',
#  'floods',
#  'landslides',
#  'qatardaynews',
#  'qatarday',
#  'welcome',
#  'patiala🙏🏻',
#  '😞🙏🏻',
#  'patiala',
#  'punjab',
#  'flood',
#  'puinstants',
#  'wmk',
#  'waheguru',
#  'human',
#  'humanity',
#  'showhumanity',
#  'insta',
#  'instagood',
#  'saveanimals',
#  'savedogs',
#  'doglover',
#  'narend',
#  'ramodi',
#  'governmentofindia',
#  'disaster',
#  'ministryofdisastermanagement',
#  'disastermanagement',
#  'haryanagovernment',
#  'unitedkingdom',
#  'unitedstates',
#  'usa',
#  'canada',
#  'dubaigovernment',
#  'sutlej',
#  '🌊the',
#  'view',
#  'look',
#  'beautiful',
#  'peaceful',
#  'actually',
#  'not',
#  'if',
#  'look',
#  'carefully',
#  'tree',
#  'submerged',
#  'river',
#  'full',
#  'fury',
#  'prayers',
#  'people',
#  'affected',
#  'flood',
#  '🙏🏻',
#  'sutluj',
#  'satluj',
#  'satlujriver',
#  'sutlejriver',
#  'punjab',
#  'punjabfloods',
#  'punjabistatus',
#  'flood',
#  'india',
#  'river',
#  'sunset',
#  'sunsetphotography',
#  'dusk',
#  'nature',
#  'naturephotography',
#  'naturesfury',
#  'viral',
#  'yolo',
#  'globalwarming',
#  'rain',
#  'climatechange',
#  'godblessus',
#  'god',
#  'godblessyou',
#  'phonephotography',
#  'bridge',
#  'bridgephotography',
#  'fyp',
#  'trending',
#  'north',
#  'india',
#  'experiencing',
#  'torrential',
#  'rain',
#  'flood',
#  'month',
#  'heatwaves',
#  'swipe',
#  'read',
#  'centering',
#  'people’s',
#  'health',
#  'education',
#  'help',
#  'u',
#  'climate',
#  'communication',
#  '🌏',
#  'if',
#  'start',
#  'designing',
#  'environmental',
#  'solution',
#  'wellbeing',
#  'lens',
#  'increase',
#  'collective',
#  'chance',
#  'limiting',
#  'climate',
#  'change',
#  'wellbeing',
#  'consists',
#  'of',
#  '➡️',
#  'body',
#  'physical',
#  'health',
#  '🫀',
#  '➡️',
#  'mind',
#  'education',
#  'mental',
#  'health',
#  '🧠',
#  'by',
#  'placing',
#  'people’s',
#  'wellbeing',
#  'centre',
#  'decisionmaking',
#  'build',
#  'political',
#  'social',
#  'support',
#  'ambitious',
#  'mitigation',
#  'action',
#  '✌🏽',
#  'please',
#  'share',
#  'resource',
#  'orgs',
#  'flood',
#  'relief',
#  'initiative',
#  'donate',
#  'know',
#  'any',
#  'flood',
#  'indianmonsoon',
#  'monsoonseason',
#  'delhirains',
#  'heatwaves',
#  'airpollution',
#  'climatecommunication',
#  'education',
#  'health',
#  'himachalpradesh',
#  'girleducation',
#  'climatecrisis',
#  'climateaction',
#  'wellbeing',
#  'nature',
#  'southasia',
#  'visuals',
#  'himachal',
#  'pradesh',
#  'praying',
#  'everyones',
#  'safety🕉️',
#  'himachalpradesh',
#  'flood',
#  'cyclone',
#  'rain',
#  'india',
#  'delhi',
#  'uttarpradesh',
#  'weather',
#  'morningnews',
#  'shimla',
#  'newdelhi',
#  'please',
#  'stay',
#  'safe',
#  'everyone',
#  'it’s',
#  'getting',
#  'dangerous',
#  'out',
#  'here',
#  '💕prayforvermont',
#  'prayingforvermont',
#  'vt',
#  'vermont',
#  'flashflood',
#  'flashflood',
#  'flood',
#  'flood',
#  'flooding',
#  'staysafe',
#  'prayforvt',
#  ...]

# %%
# %pip install wordcloud
# %pip install --upgrade Pillow
# Out:
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.10/dist-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from wordcloud) (1.25.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (9.4.0)
# Collecting Pillow
#   Downloading pillow-10.2.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 17.4 MB/s eta 0:00:00
# Installing collected packages: Pillow
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imageio 2.31.6 requires pillow<10.1.0,>=8.3.2, but you have pillow 10.2.0 which is incompatible.
# Successfully installed Pillow-10.2.0

# %%
from collections import Counter
from PIL import Image
from wordcloud import WordCloud


temp_dict = Counter(sentiment_caption_graph)
wc = WordCloud(background_color="black", max_words=100,relative_scaling=0.5,normalize_plurals=False).generate_from_frequencies(temp_dict)
plt.imshow(wc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-f5b8e2cff93e> in <cell line: 6>()
#       4
#       5
# ----> 6 temp_dict = Counter(sentiment_caption_graph)
#       7 wc = WordCloud(background_color="black", max_words=100,relative_scaling=0.5,normalize_plurals=False).generate_from_frequencies(temp_dict)
#       8 plt.imshow(wc)
#
# NameError: name 'sentiment_caption_graph' is not defined
